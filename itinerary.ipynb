# %%
class DaySet:
    def __init__(self,day,date,day_limit):
        self.day = day
        self.day_limit = day_limit
        self.date = date
        self.attractions = []

class Timing:
    def __init__(self,day,open,st_time,en_time):
        self.day = day
        self.open = open
        self.st_time = st_time
        self.en_time = en_time

class Attraction:
    def __init__(self,id:int,duration:int,timings:list,rating:float,location:list,at_type:int):
        self.id = id
        self.duration = duration
        self.rating = rating
        self.location = location
        self.type = at_type
        self.timings = timings
    
    # Define comparison for less than
    def __lt__(self, other):
        return self.rating > other.rating

# %%
from geopy.distance import geodesic

def time_between_locations(l1:list,l2:list):
    distance = geodesic(l1, l2).kilometers
    travel_time = distance / 30  # Assuming average speed of 30 km/h
    return travel_time

def get_timing(day_set:DaySet, attraction:Attraction):
    if len(day_set.attractions) == 0:
        return 0
    
    best_time = float("inf")
    for selected_attraction in day_set.attractions:
        travel_time = time_between_locations(selected_attraction.location, attraction.location)
        best_time = min(best_time,travel_time)
    return best_time

def average_rating(attractions:list):
    total_rating = 0
    total_duration = 0
    for attraction in attractions:
        total_rating += attraction.rating
        total_duration += attraction.duration
    return total_rating/total_duration

def get_effective_rating(day_set:DaySet, attraction:Attraction,time_penelty_factor:float):
    LENIENT_TIMING = 0.5
    effective_timing = max(get_timing(day_set,attraction) - LENIENT_TIMING,0)
    effective_rating = attraction.rating - effective_timing*time_penelty_factor

def get_rating_matrix(day_sets:list,attractions:list): 
    AVG_RATING = average_rating(attractions)
    rating = []
    for i in range(len(day_sets)):
        for j in range(len(attractions)):
                cur_day = day_sets[i].day
                new_day_set = day_sets[i].attractions + [attractions[j]]
                if day_sets[i].day != attraction[j].timings.day or get_day_iternery(converted_attractions(new_day_set))==None: #attraction is closed on that day or not possible
                    rating.append([i,j,0])
                else:
                    effective_rating = get_effective_rating(day_sets[i],attractions[j])
                    rating.append([i,j,effective_rating])
    rating.sort(key=lambda x: x[2])
    return rating

# %%
import sqlite3

MAX_RATING = 40
STD_TIMING = [
    (-1, -1, 0, 1, '1000', '1800'), 
    (-1, -1, 1, 1, '1000', '1800'), 
    (-1, -1, 2, 1, '1000', '1800'), 
    (-1, -1, 3, 1, '1000', '1800'), 
    (-1, -1, 4, 1, '1000', '1800'), 
    (-1, -1, 5, 1, '1000', '1800'), 
    (-1, -1, 6, 1, '1000', '1800')
    ]

ALL_TIMING = [
    (-1, -1, 0, 1, '0800', '2400'), 
    (-1, -1, 1, 1, '0800', '2400'), 
    (-1, -1, 2, 1, '0800', '2400'), 
    (-1, -1, 3, 1, '0800', '2400'), 
    (-1, -1, 4, 1, '0800', '2400'), 
    (-1, -1, 5, 1, '0800', '2400'), 
    (-1, -1, 6, 1, '0800', '2400')
    ]


def open247(day_results):
    for day in day_results:
        if day[3] == 1:
            return 0
    return 1

def get_attraction_list(requirement):
    types_string = ",".join(["'"+str(type_id)+"'" for type_id in requirement["types"]])
    query = f"""
    SELECT * FROM Attractions
    WHERE city_id = (SELECT id FROM Cities WHERE name = '{requirement["city"]}') 
    AND type_id IN (SELECT id FROM Types WHERE name IN ({types_string}))
    """
    conn = sqlite3.connect("../Data/tws.db")
    cursor = conn.cursor()
    cursor.execute(query)
    attractions_results = cursor.fetchall()


    attractions = []
    for row in attractions_results:
        id, duration, rating, location, at_type = row[0],row[5],row[6],[row[8],row[9]],row[2]
        type_query = f"""
            SELECT name from Types
            WHERE id = {at_type}
        """
        cursor.execute(type_query)
        at_type = cursor.fetchall()[0][0]
        if id in requirement["exclude"]:
            continue
        if id in requirement["include"]:
            rating = MAX_RATING
        if id in requirement["duration"][0]:
            rating = MAX_RATING
            duration = requirement["duration"][1][requirement["duration"][0].index(id)]    
    
        time_query = f"""
            SELECT * FROM OperationHours
            WHERE attraction_id = {id}
        """     
        cursor.execute(time_query)
        day_results = cursor.fetchall()
        if len(day_results)==1:
            day_results = STD_TIMING
        if open247(day_results):
            day_results = ALL_TIMING
            
        timings=[]
        for i in range(0,7):
            timings.append(Timing(
                i,
                int(day_results[i][3]),
                int(day_results[i][4]) if day_results[i][4] is not None else -1,
                int(day_results[i][5]) if day_results[i][5] is not None else -1
            ))
        attractions.append(Attraction(id,duration,timings,rating,location,at_type))
    
    return(attractions)


requirement = {
    "city" : "London",
    "st_date" : "03-08-23",
    "en_date" : "04-08-23",
    "types" : ["Historical & Cultural","Food & Drinks"],
    "exclude" : [2],
    "include" : [3],
    "duration" : [[4,5],[2,6]],
}

for ele in get_attraction_list(requirement):
    print(ele.__dict__)
    for tm in ele.__dict__['timings']:
        print(tm.__dict__)
# Out:
# {'id': 3, 'duration': 3, 'rating': 40, 'location': [51.50811239999999, -0.0759493], 'type': 'Historical & Cultural', 'timings': [<__main__.Timing object at 0x105de4070>, <__main__.Timing object at 0x105de4100>, <__main__.Timing object at 0x105d776d0>, <__main__.Timing object at 0x105c6a4f0>, <__main__.Timing object at 0x105c6a070>, <__main__.Timing object at 0x105c6a7f0>, <__main__.Timing object at 0x105dd6f10>]}
# {'day': 0, 'open': 1, 'st_time': 900, 'en_time': 1730}
# {'day': 1, 'open': 1, 'st_time': 900, 'en_time': 1730}
# {'day': 2, 'open': 1, 'st_time': 900, 'en_time': 1730}
# {'day': 3, 'open': 1, 'st_time': 900, 'en_time': 1730}
# {'day': 4, 'open': 1, 'st_time': 900, 'en_time': 1730}
# {'day': 5, 'open': 1, 'st_time': 900, 'en_time': 1730}
# {'day': 6, 'open': 1, 'st_time': 900, 'en_time': 1730}
# {'id': 4, 'duration': 2, 'rating': 40, 'location': [51.5021585, -0.1293572], 'type': 'Historical & Cultural', 'timings': [<__main__.Timing object at 0x105dd68e0>, <__main__.Timing object at 0x105dc9b50>, <__main__.Timing object at 0x105dc9b20>, <__main__.Timing object at 0x105dc9d90>, <__main__.Timing object at 0x105dc97f0>, <__main__.Timing object at 0x105dc9a90>, <__main__.Timing object at 0x105dc9c10>]}
# {'day': 0, 'open': 1, 'st_time': 930, 'en_time': 1800}
# {'day': 1, 'open': 1, 'st_time': 930, 'en_time': 1800}
# {'day': 2, 'open': 1, 'st_time': 930, 'en_time': 1800}
# {'day': 3, 'open': 1, 'st_time': 930, 'en_time': 1800}
# {'day': 4, 'open': 1, 'st_time': 930, 'en_time': 1800}
# {'day': 5, 'open': 1, 'st_time': 930, 'en_time': 1800}
# {'day': 6, 'open': 1, 'st_time': 930, 'en_time': 1800}
# {'id': 5, 'duration': 6, 'rating': 40, 'location': [51.49671499999999, -0.1763672], 'type': 'Historical & Cultural', 'timings': [<__main__.Timing object at 0x105d6ee20>, <__main__.Timing object at 0x105d93fa0>, <__main__.Timing object at 0x105d93160>, <__main__.Timing object at 0x105d93d60>, <__main__.Timing object at 0x105d93520>, <__main__.Timing object at 0x105d936a0>, <__main__.Timing object at 0x105d93f10>]}
# {'day': 0, 'open': 1, 'st_time': 1000, 'en_time': 1750}
# {'day': 1, 'open': 1, 'st_time': 1000, 'en_time': 1750}
# {'day': 2, 'open': 1, 'st_time': 1000, 'en_time': 1750}
# {'day': 3, 'open': 1, 'st_time': 1000, 'en_time': 1750}
# {'day': 4, 'open': 1, 'st_time': 1000, 'en_time': 1750}
# {'day': 5, 'open': 1, 'st_time': 1000, 'en_time': 1750}
# {'day': 6, 'open': 1, 'st_time': 1000, 'en_time': 1750}
# {'id': 6, 'duration': 3, 'rating': 22.59, 'location': [51.5194133, -0.1269566], 'type': 'Historical & Cultural', 'timings': [<__main__.Timing object at 0x105d93f40>, <__main__.Timing object at 0x105d93a30>, <__main__.Timing object at 0x105d931f0>, <__main__.Timing object at 0x105d939d0>, <__main__.Timing object at 0x105dd9070>, <__main__.Timing object at 0x105dd90a0>, <__main__.Timing object at 0x105dd9100>]}
# {'day': 0, 'open': 1, 'st_time': 1000, 'en_time': 1700}
# {'day': 1, 'open': 1, 'st_time': 1000, 'en_time': 1700}
# {'day': 2, 'open': 1, 'st_time': 1000, 'en_time': 1700}
# {'day': 3, 'open': 1, 'st_time': 1000, 'en_time': 1700}
# {'day': 4, 'open': 1, 'st_time': 1000, 'en_time': 2030}
# {'day': 5, 'open': 1, 'st_time': 1000, 'en_time': 1700}
# {'day': 6, 'open': 1, 'st_time': 1000, 'en_time': 1700}
# {'id': 7, 'duration': 2, 'rating': 21.28, 'location': [51.5031864, -0.1195192], 'type': 'Historical & Cultural', 'timings': [<__main__.Timing object at 0x105dd9160>, <__main__.Timing object at 0x105dd4370>, <__main__.Timing object at 0x105dd43d0>, <__main__.Timing object at 0x105dd4430>, <__main__.Timing object at 0x105dd4490>, <__main__.Timing object at 0x105dd44f0>, <__main__.Timing object at 0x105dd4550>]}
# {'day': 0, 'open': 1, 'st_time': 1000, 'en_time': 2030}
# {'day': 1, 'open': 1, 'st_time': 1000, 'en_time': 2030}
# {'day': 2, 'open': 1, 'st_time': 1100, 'en_time': 1800}
# {'day': 3, 'open': 1, 'st_time': 1000, 'en_time': 2030}
# {'day': 4, 'open': 1, 'st_time': 1000, 'en_time': 2030}
# {'day': 5, 'open': 1, 'st_time': 1000, 'en_time': 2030}
# {'day': 6, 'open': 1, 'st_time': 1000, 'en_time': 2030}
# {'id': 8, 'duration': 2, 'rating': 21.12, 'location': [51.5054564, -0.07535649999999999], 'type': 'Historical & Cultural', 'timings': [<__main__.Timing object at 0x105dd45b0>, <__main__.Timing object at 0x105dd4640>, <__main__.Timing object at 0x105dd46a0>, <__main__.Timing object at 0x105dd4700>, <__main__.Timing object at 0x105dd4760>, <__main__.Timing object at 0x105dd47c0>, <__main__.Timing object at 0x105dd4820>]}
# {'day': 0, 'open': 1, 'st_time': 930, 'en_time': 1800}
# {'day': 1, 'open': 1, 'st_time': 930, 'en_time': 1800}
# {'day': 2, 'open': 1, 'st_time': 930, 'en_time': 1800}
# {'day': 3, 'open': 1, 'st_time': 930, 'en_time': 1800}
# {'day': 4, 'open': 1, 'st_time': 930, 'en_time': 1800}
# {'day': 5, 'open': 1, 'st_time': 930, 'en_time': 1800}
# {'day': 6, 'open': 1, 'st_time': 930, 'en_time': 1800}
# {'id': 9, 'duration': 3, 'rating': 21.0, 'location': [51.4966392, -0.17218], 'type': 'Historical & Cultural', 'timings': [<__main__.Timing object at 0x105dd4880>, <__main__.Timing object at 0x105dd4910>, <__main__.Timing object at 0x105dd4970>, <__main__.Timing object at 0x105dd49d0>, <__main__.Timing object at 0x105dd4a30>, <__main__.Timing object at 0x105dd4a90>, <__main__.Timing object at 0x105dd4af0>]}
# {'day': 0, 'open': 1, 'st_time': 1000, 'en_time': 1745}
# {'day': 1, 'open': 1, 'st_time': 1000, 'en_time': 1745}
# {'day': 2, 'open': 1, 'st_time': 1000, 'en_time': 1745}
# {'day': 3, 'open': 1, 'st_time': 1000, 'en_time': 1745}
# {'day': 4, 'open': 1, 'st_time': 1000, 'en_time': 2200}
# {'day': 5, 'open': 1, 'st_time': 1000, 'en_time': 1745}
# {'day': 6, 'open': 1, 'st_time': 1000, 'en_time': 1745}
# {'id': 10, 'duration': 2, 'rating': 20.06, 'location': [51.49936950000001, -0.1272993], 'type': 'Historical & Cultural', 'timings': [<__main__.Timing object at 0x105dd4b50>, <__main__.Timing object at 0x105dd4be0>, <__main__.Timing object at 0x105dd4c40>, <__main__.Timing object at 0x105dd4ca0>, <__main__.Timing object at 0x105dd4d00>, <__main__.Timing object at 0x105dd4d60>, <__main__.Timing object at 0x105dd4dc0>]}
# {'day': 0, 'open': 1, 'st_time': 1000, 'en_time': 1800}
# {'day': 1, 'open': 1, 'st_time': 1000, 'en_time': 1800}
# {'day': 2, 'open': 1, 'st_time': 1000, 'en_time': 1800}
# {'day': 3, 'open': 1, 'st_time': 1000, 'en_time': 1800}
# {'day': 4, 'open': 1, 'st_time': 1000, 'en_time': 1800}
# {'day': 5, 'open': 1, 'st_time': 1000, 'en_time': 1800}
# {'day': 6, 'open': 1, 'st_time': 1000, 'en_time': 1800}
# {'id': 11, 'duration': 3, 'rating': 19.6, 'location': [51.5116571, -0.1240436], 'type': 'Historical & Cultural', 'timings': [<__main__.Timing object at 0x105dd4e20>, <__main__.Timing object at 0x105dd4ee0>, <__main__.Timing object at 0x105dd4f40>, <__main__.Timing object at 0x105dd4fa0>, <__main__.Timing object at 0x105ddb040>, <__main__.Timing object at 0x105ddb0a0>, <__main__.Timing object at 0x105ddb100>]}
# {'day': 0, 'open': 1, 'st_time': 1000, 'en_time': 1800}
# {'day': 1, 'open': 1, 'st_time': 1000, 'en_time': 1800}
# {'day': 2, 'open': 1, 'st_time': 1000, 'en_time': 1800}
# {'day': 3, 'open': 1, 'st_time': 1000, 'en_time': 1800}
# {'day': 4, 'open': 1, 'st_time': 1000, 'en_time': 1800}
# {'day': 5, 'open': 1, 'st_time': 1000, 'en_time': 1800}
# {'day': 6, 'open': 1, 'st_time': 1000, 'en_time': 1800}
# {'id': 13, 'duration': 2, 'rating': 19.65, 'location': [51.4994794, -0.1248092], 'type': 'Historical & Cultural', 'timings': [<__main__.Timing object at 0x105ddbc10>, <__main__.Timing object at 0x105ddbcd0>, <__main__.Timing object at 0x105ddbd30>, <__main__.Timing object at 0x105ddbd90>, <__main__.Timing object at 0x105ddbdf0>, <__main__.Timing object at 0x105ddbe50>, <__main__.Timing object at 0x105ddbeb0>]}
# {'day': 0, 'open': 1, 'st_time': 1000, 'en_time': 1800}
# {'day': 1, 'open': 1, 'st_time': 1000, 'en_time': 1800}
# {'day': 2, 'open': 1, 'st_time': 1000, 'en_time': 1800}
# {'day': 3, 'open': 1, 'st_time': 1000, 'en_time': 1800}
# {'day': 4, 'open': 1, 'st_time': 1000, 'en_time': 1800}
# {'day': 5, 'open': 1, 'st_time': 1000, 'en_time': 1800}
# {'day': 6, 'open': 1, 'st_time': 1000, 'en_time': 1800}
# {'id': 16, 'duration': 1, 'rating': 19.84, 'location': [51.50072919999999, -0.1246254], 'type': 'Historical & Cultural', 'timings': [<__main__.Timing object at 0x105ddbf10>, <__main__.Timing object at 0x105ddbfd0>, <__main__.Timing object at 0x105df7070>, <__main__.Timing object at 0x105df70d0>, <__main__.Timing object at 0x105df7130>, <__main__.Timing object at 0x105df7190>, <__main__.Timing object at 0x105df71f0>]}
# {'day': 0, 'open': 1, 'st_time': 1000, 'en_time': 1800}
# {'day': 1, 'open': 1, 'st_time': 1000, 'en_time': 1800}
# {'day': 2, 'open': 1, 'st_time': 1000, 'en_time': 1800}
# {'day': 3, 'open': 1, 'st_time': 1000, 'en_time': 1800}
# {'day': 4, 'open': 1, 'st_time': 1000, 'en_time': 1800}
# {'day': 5, 'open': 1, 'st_time': 1000, 'en_time': 1800}
# {'day': 6, 'open': 1, 'st_time': 1000, 'en_time': 1800}
# {'id': 17, 'duration': 3, 'rating': 19.36, 'location': [51.501364, -0.14189], 'type': 'Historical & Cultural', 'timings': [<__main__.Timing object at 0x105df7250>, <__main__.Timing object at 0x105df7310>, <__main__.Timing object at 0x105df7370>, <__main__.Timing object at 0x105df73d0>, <__main__.Timing object at 0x105df7430>, <__main__.Timing object at 0x105df7490>, <__main__.Timing object at 0x105df74f0>]}
# {'day': 0, 'open': 1, 'st_time': 930, 'en_time': 1930}
# {'day': 1, 'open': 0, 'st_time': -1, 'en_time': -1}
# {'day': 2, 'open': 0, 'st_time': -1, 'en_time': -1}
# {'day': 3, 'open': 1, 'st_time': 930, 'en_time': 1930}
# {'day': 4, 'open': 1, 'st_time': 930, 'en_time': 1930}
# {'day': 5, 'open': 1, 'st_time': 930, 'en_time': 1930}
# {'day': 6, 'open': 1, 'st_time': 930, 'en_time': 1930}
# {'id': 21, 'duration': 2, 'rating': 18.6, 'location': [51.5044028, -0.08653309999999999], 'type': 'Historical & Cultural', 'timings': [<__main__.Timing object at 0x105df7550>, <__main__.Timing object at 0x105df7610>, <__main__.Timing object at 0x105df7670>, <__main__.Timing object at 0x105df76d0>, <__main__.Timing object at 0x105df7730>, <__main__.Timing object at 0x105df7790>, <__main__.Timing object at 0x105df77f0>]}
# {'day': 0, 'open': 0, 'st_time': -1, 'en_time': -1}
# {'day': 1, 'open': 0, 'st_time': -1, 'en_time': -1}
# {'day': 2, 'open': 1, 'st_time': 1000, 'en_time': 2200}
# {'day': 3, 'open': 1, 'st_time': 1000, 'en_time': 2200}
# {'day': 4, 'open': 1, 'st_time': 1000, 'en_time': 2200}
# {'day': 5, 'open': 1, 'st_time': 1000, 'en_time': 2200}
# {'day': 6, 'open': 1, 'st_time': 1000, 'en_time': 2200}
# {'id': 24, 'duration': 3, 'rating': 15.61, 'location': [51.5669188, -0.1467755], 'type': 'Historical & Cultural', 'timings': [<__main__.Timing object at 0x105df7850>, <__main__.Timing object at 0x105df7910>, <__main__.Timing object at 0x105df7970>, <__main__.Timing object at 0x105df79d0>, <__main__.Timing object at 0x105df7a30>, <__main__.Timing object at 0x105df7a90>, <__main__.Timing object at 0x105df7af0>]}
# {'day': 0, 'open': 1, 'st_time': 1000, 'en_time': 1700}
# {'day': 1, 'open': 1, 'st_time': 1000, 'en_time': 1700}
# {'day': 2, 'open': 1, 'st_time': 1000, 'en_time': 1700}
# {'day': 3, 'open': 1, 'st_time': 1000, 'en_time': 1700}
# {'day': 4, 'open': 1, 'st_time': 1000, 'en_time': 1700}
# {'day': 5, 'open': 1, 'st_time': 1000, 'en_time': 1700}
# {'day': 6, 'open': 1, 'st_time': 1000, 'en_time': 1700}
# {'id': 28, 'duration': 4, 'rating': 16.52, 'location': [51.59807900000001, -0.2383246], 'type': 'Historical & Cultural', 'timings': [<__main__.Timing object at 0x105df7b50>, <__main__.Timing object at 0x105df7c10>, <__main__.Timing object at 0x105df7c70>, <__main__.Timing object at 0x105df7cd0>, <__main__.Timing object at 0x105df7d30>, <__main__.Timing object at 0x105df7d90>, <__main__.Timing object at 0x105df7df0>]}
# {'day': 0, 'open': 1, 'st_time': 1000, 'en_time': 1700}
# {'day': 1, 'open': 1, 'st_time': 1000, 'en_time': 1700}
# {'day': 2, 'open': 1, 'st_time': 1000, 'en_time': 1700}
# {'day': 3, 'open': 1, 'st_time': 1000, 'en_time': 1700}
# {'day': 4, 'open': 1, 'st_time': 1000, 'en_time': 1700}
# {'day': 5, 'open': 1, 'st_time': 1000, 'en_time': 1700}
# {'day': 6, 'open': 1, 'st_time': 1000, 'en_time': 1700}
# {'id': 30, 'duration': 2, 'rating': 14.56, 'location': [51.5163012, -0.2110215], 'type': 'Historical & Cultural', 'timings': [<__main__.Timing object at 0x105df7e50>, <__main__.Timing object at 0x105df7f10>, <__main__.Timing object at 0x105df7f70>, <__main__.Timing object at 0x105df7fd0>, <__main__.Timing object at 0x105dfa070>, <__main__.Timing object at 0x105dfa0d0>, <__main__.Timing object at 0x105dfa130>]}
# {'day': 0, 'open': 1, 'st_time': 1000, 'en_time': 1800}
# {'day': 1, 'open': 1, 'st_time': 1000, 'en_time': 1800}
# {'day': 2, 'open': 1, 'st_time': 1000, 'en_time': 1800}
# {'day': 3, 'open': 1, 'st_time': 1000, 'en_time': 1800}
# {'day': 4, 'open': 1, 'st_time': 1000, 'en_time': 1800}
# {'day': 5, 'open': 1, 'st_time': 1000, 'en_time': 1800}
# {'day': 6, 'open': 1, 'st_time': 1100, 'en_time': 1700}
# {'id': 31, 'duration': 2, 'rating': 15.88, 'location': [51.5543702, -0.1095773], 'type': 'Historical & Cultural', 'timings': [<__main__.Timing object at 0x105dfa190>, <__main__.Timing object at 0x105dfa250>, <__main__.Timing object at 0x105dfa2b0>, <__main__.Timing object at 0x105dfa310>, <__main__.Timing object at 0x105dfa370>, <__main__.Timing object at 0x105dfa3d0>, <__main__.Timing object at 0x105dfa430>]}
# {'day': 0, 'open': 1, 'st_time': 1000, 'en_time': 1800}
# {'day': 1, 'open': 1, 'st_time': 1000, 'en_time': 1800}
# {'day': 2, 'open': 1, 'st_time': 1000, 'en_time': 1800}
# {'day': 3, 'open': 1, 'st_time': 1000, 'en_time': 1800}
# {'day': 4, 'open': 1, 'st_time': 1000, 'en_time': 1800}
# {'day': 5, 'open': 1, 'st_time': 1000, 'en_time': 1800}
# {'day': 6, 'open': 1, 'st_time': 1000, 'en_time': 1800}
# {'id': 32, 'duration': 3, 'rating': 14.46, 'location': [51.43450399999999, -0.213367], 'type': 'Historical & Cultural', 'timings': [<__main__.Timing object at 0x105dfa490>, <__main__.Timing object at 0x105dfa550>, <__main__.Timing object at 0x105dfa5b0>, <__main__.Timing object at 0x105dfa610>, <__main__.Timing object at 0x105dfa670>, <__main__.Timing object at 0x105dfa6d0>, <__main__.Timing object at 0x105dfa730>]}
# {'day': 0, 'open': 1, 'st_time': 1000, 'en_time': 1730}
# {'day': 1, 'open': 1, 'st_time': 1000, 'en_time': 1730}
# {'day': 2, 'open': 1, 'st_time': 1000, 'en_time': 1730}
# {'day': 3, 'open': 1, 'st_time': 1000, 'en_time': 1730}
# {'day': 4, 'open': 1, 'st_time': 1000, 'en_time': 1730}
# {'day': 5, 'open': 1, 'st_time': 1000, 'en_time': 1730}
# {'day': 6, 'open': 1, 'st_time': 1000, 'en_time': 1730}
# {'id': 33, 'duration': 3, 'rating': 14.38, 'location': [51.5075598, -0.0238525], 'type': 'Historical & Cultural', 'timings': [<__main__.Timing object at 0x105dfa790>, <__main__.Timing object at 0x105dfa850>, <__main__.Timing object at 0x105dfa8b0>, <__main__.Timing object at 0x105dfa910>, <__main__.Timing object at 0x105dfa970>, <__main__.Timing object at 0x105dfa9d0>, <__main__.Timing object at 0x105dfaa30>]}
# {'day': 0, 'open': 1, 'st_time': 1000, 'en_time': 1700}
# {'day': 1, 'open': 1, 'st_time': 1000, 'en_time': 1700}
# {'day': 2, 'open': 1, 'st_time': 1000, 'en_time': 1700}
# {'day': 3, 'open': 1, 'st_time': 1000, 'en_time': 1700}
# {'day': 4, 'open': 1, 'st_time': 1000, 'en_time': 1700}
# {'day': 5, 'open': 1, 'st_time': 1000, 'en_time': 1700}
# {'day': 6, 'open': 1, 'st_time': 1000, 'en_time': 1700}
# {'id': 35, 'duration': 2, 'rating': 13.79, 'location': [51.5235861, -0.1162944], 'type': 'Historical & Cultural', 'timings': [<__main__.Timing object at 0x105dfaa90>, <__main__.Timing object at 0x105dfab50>, <__main__.Timing object at 0x105dfabb0>, <__main__.Timing object at 0x105dfac10>, <__main__.Timing object at 0x105dfac70>, <__main__.Timing object at 0x105dfacd0>, <__main__.Timing object at 0x105dfad30>]}
# {'day': 0, 'open': 0, 'st_time': -1, 'en_time': -1}
# {'day': 1, 'open': 0, 'st_time': -1, 'en_time': -1}
# {'day': 2, 'open': 1, 'st_time': 1000, 'en_time': 1700}
# {'day': 3, 'open': 1, 'st_time': 1000, 'en_time': 1700}
# {'day': 4, 'open': 1, 'st_time': 1000, 'en_time': 1700}
# {'day': 5, 'open': 1, 'st_time': 1000, 'en_time': 1700}
# {'day': 6, 'open': 1, 'st_time': 1000, 'en_time': 1700}
# {'id': 36, 'duration': 2, 'rating': 12.44, 'location': [51.48587979999999, -0.1131627], 'type': 'Food & Drinks', 'timings': [<__main__.Timing object at 0x105dfad90>, <__main__.Timing object at 0x105dfae80>, <__main__.Timing object at 0x105dfaee0>, <__main__.Timing object at 0x105dfaf40>, <__main__.Timing object at 0x105dfafa0>, <__main__.Timing object at 0x105dfe040>, <__main__.Timing object at 0x105dfe0a0>]}
# {'day': 0, 'open': 0, 'st_time': -1, 'en_time': -1}
# {'day': 1, 'open': 0, 'st_time': -1, 'en_time': -1}
# {'day': 2, 'open': 1, 'st_time': 1100, 'en_time': 1830}
# {'day': 3, 'open': 1, 'st_time': 1100, 'en_time': 1830}
# {'day': 4, 'open': 1, 'st_time': 1100, 'en_time': 1830}
# {'day': 5, 'open': 1, 'st_time': 1100, 'en_time': 1830}
# {'day': 6, 'open': 1, 'st_time': 1100, 'en_time': 1830}
# {'id': 37, 'duration': 2, 'rating': 12.38, 'location': [51.5137169, -0.1604557], 'type': 'Historical & Cultural', 'timings': [<__main__.Timing object at 0x105dfe100>, <__main__.Timing object at 0x105dfe1c0>, <__main__.Timing object at 0x105dfe220>, <__main__.Timing object at 0x105dfe280>, <__main__.Timing object at 0x105dfe2e0>, <__main__.Timing object at 0x105dfe340>, <__main__.Timing object at 0x105dfe3a0>]}
# {'day': 0, 'open': 1, 'st_time': 1000, 'en_time': 1800}
# {'day': 1, 'open': 1, 'st_time': 1000, 'en_time': 1800}
# {'day': 2, 'open': 1, 'st_time': 1000, 'en_time': 1800}
# {'day': 3, 'open': 1, 'st_time': 1000, 'en_time': 1800}
# {'day': 4, 'open': 1, 'st_time': 1000, 'en_time': 1800}
# {'day': 5, 'open': 1, 'st_time': 1000, 'en_time': 1800}
# {'day': 6, 'open': 1, 'st_time': 1000, 'en_time': 1800}
# {'id': 38, 'duration': 1, 'rating': 12.81, 'location': [51.5107887, -0.06790699999999998], 'type': 'Historical & Cultural', 'timings': [<__main__.Timing object at 0x105dfe400>, <__main__.Timing object at 0x105dfe4c0>, <__main__.Timing object at 0x105dfe520>, <__main__.Timing object at 0x105dfe580>, <__main__.Timing object at 0x105dfe5e0>, <__main__.Timing object at 0x105dfe640>, <__main__.Timing object at 0x105dfe6a0>]}
# {'day': 0, 'open': 1, 'st_time': 930, 'en_time': 1800}
# {'day': 1, 'open': 1, 'st_time': 930, 'en_time': 1800}
# {'day': 2, 'open': 1, 'st_time': 930, 'en_time': 1800}
# {'day': 3, 'open': 1, 'st_time': 930, 'en_time': 1800}
# {'day': 4, 'open': 1, 'st_time': 930, 'en_time': 1800}
# {'day': 5, 'open': 1, 'st_time': 930, 'en_time': 1800}
# {'day': 6, 'open': 1, 'st_time': 930, 'en_time': 1800}
# {'id': 39, 'duration': 1, 'rating': 12.96, 'location': [51.5050283, -0.0885991], 'type': 'Historical & Cultural', 'timings': [<__main__.Timing object at 0x105dfe700>, <__main__.Timing object at 0x105dfe7c0>, <__main__.Timing object at 0x105dfe820>, <__main__.Timing object at 0x105dfe880>, <__main__.Timing object at 0x105dfe8e0>, <__main__.Timing object at 0x105dfe940>, <__main__.Timing object at 0x105dfe9a0>]}
# {'day': 0, 'open': 0, 'st_time': -1, 'en_time': -1}
# {'day': 1, 'open': 0, 'st_time': -1, 'en_time': -1}
# {'day': 2, 'open': 0, 'st_time': -1, 'en_time': -1}
# {'day': 3, 'open': 1, 'st_time': 1030, 'en_time': 1700}
# {'day': 4, 'open': 1, 'st_time': 1030, 'en_time': 1700}
# {'day': 5, 'open': 1, 'st_time': 1030, 'en_time': 1700}
# {'day': 6, 'open': 1, 'st_time': 1030, 'en_time': 1700}
# {'id': 41, 'duration': 4, 'rating': 13.64, 'location': [51.51604359999999, -0.2048339], 'type': 'Food & Drinks', 'timings': [<__main__.Timing object at 0x105dfea00>, <__main__.Timing object at 0x105dfeac0>, <__main__.Timing object at 0x105dfeb20>, <__main__.Timing object at 0x105dfeb80>, <__main__.Timing object at 0x105dfebe0>, <__main__.Timing object at 0x105dfec40>, <__main__.Timing object at 0x105dfeca0>]}
# {'day': 0, 'open': 1, 'st_time': 1000, 'en_time': 1800}
# {'day': 1, 'open': 1, 'st_time': 1000, 'en_time': 1800}
# {'day': 2, 'open': 1, 'st_time': 1000, 'en_time': 1800}
# {'day': 3, 'open': 1, 'st_time': 1000, 'en_time': 1800}
# {'day': 4, 'open': 1, 'st_time': 1000, 'en_time': 1800}
# {'day': 5, 'open': 1, 'st_time': 1000, 'en_time': 1800}
# {'day': 6, 'open': 1, 'st_time': 1000, 'en_time': 1800}
# {'id': 42, 'duration': 2, 'rating': 12.61, 'location': [17.3821696, 78.4703542], 'type': 'Historical & Cultural', 'timings': [<__main__.Timing object at 0x105dfed00>, <__main__.Timing object at 0x105dfedc0>, <__main__.Timing object at 0x105dfee20>, <__main__.Timing object at 0x105dfee80>, <__main__.Timing object at 0x105dfeee0>, <__main__.Timing object at 0x105dfef40>, <__main__.Timing object at 0x105dfefa0>]}
# {'day': 0, 'open': 1, 'st_time': 1100, 'en_time': 2230}
# {'day': 1, 'open': 1, 'st_time': 1100, 'en_time': 2230}
# {'day': 2, 'open': 1, 'st_time': 1100, 'en_time': 2230}
# {'day': 3, 'open': 1, 'st_time': 1100, 'en_time': 2230}
# {'day': 4, 'open': 1, 'st_time': 1100, 'en_time': 2230}
# {'day': 5, 'open': 1, 'st_time': 1100, 'en_time': 2230}
# {'day': 6, 'open': 0, 'st_time': -1, 'en_time': -1}
# {'id': 46, 'duration': 4, 'rating': 13.57, 'location': [51.5153551, -0.1159625], 'type': 'Historical & Cultural', 'timings': [<__main__.Timing object at 0x105e01040>, <__main__.Timing object at 0x105e01100>, <__main__.Timing object at 0x105e01160>, <__main__.Timing object at 0x105e011c0>, <__main__.Timing object at 0x105e01220>, <__main__.Timing object at 0x105e01280>, <__main__.Timing object at 0x105e012e0>]}
# {'day': 0, 'open': 0, 'st_time': -1, 'en_time': -1}
# {'day': 1, 'open': 1, 'st_time': 1000, 'en_time': 1700}
# {'day': 2, 'open': 1, 'st_time': 1000, 'en_time': 1700}
# {'day': 3, 'open': 1, 'st_time': 1000, 'en_time': 1700}
# {'day': 4, 'open': 1, 'st_time': 1000, 'en_time': 1700}
# {'day': 5, 'open': 1, 'st_time': 1000, 'en_time': 1700}
# {'day': 6, 'open': 0, 'st_time': -1, 'en_time': -1}
# {'id': 48, 'duration': 3, 'rating': 12.78, 'location': [51.5139152, -0.1050263], 'type': 'Food & Drinks', 'timings': [<__main__.Timing object at 0x105e01340>, <__main__.Timing object at 0x105e01400>, <__main__.Timing object at 0x105e01460>, <__main__.Timing object at 0x105e014c0>, <__main__.Timing object at 0x105e01520>, <__main__.Timing object at 0x105e01580>, <__main__.Timing object at 0x105e015e0>]}
# {'day': 0, 'open': 1, 'st_time': 1600, 'en_time': 2200}
# {'day': 1, 'open': 1, 'st_time': 1600, 'en_time': 2200}
# {'day': 2, 'open': 1, 'st_time': 1600, 'en_time': 2200}
# {'day': 3, 'open': 1, 'st_time': 1600, 'en_time': 2200}
# {'day': 4, 'open': 1, 'st_time': 1600, 'en_time': 2200}
# {'day': 5, 'open': 1, 'st_time': 1400, 'en_time': 2200}
# {'day': 6, 'open': 0, 'st_time': -1, 'en_time': -1}
# {'id': 49, 'duration': 2, 'rating': 12.86, 'location': [51.4452263, -0.1440073], 'type': 'Food & Drinks', 'timings': [<__main__.Timing object at 0x105e01640>, <__main__.Timing object at 0x105e01700>, <__main__.Timing object at 0x105e01760>, <__main__.Timing object at 0x105e017c0>, <__main__.Timing object at 0x105e01820>, <__main__.Timing object at 0x105e01880>, <__main__.Timing object at 0x105e018e0>]}
# {'day': 0, 'open': 1, 'st_time': 1200, 'en_time': 1730}
# {'day': 1, 'open': 1, 'st_time': 1200, 'en_time': 1730}
# {'day': 2, 'open': 1, 'st_time': 1200, 'en_time': 1730}
# {'day': 3, 'open': 1, 'st_time': 1200, 'en_time': 1730}
# {'day': 4, 'open': 1, 'st_time': 1200, 'en_time': 1730}
# {'day': 5, 'open': 1, 'st_time': 1200, 'en_time': 1730}
# {'day': 6, 'open': 0, 'st_time': -1, 'en_time': -1}
# {'id': 51, 'duration': 1, 'rating': 12.06, 'location': [51.509715, -0.0824601], 'type': 'Historical & Cultural', 'timings': [<__main__.Timing object at 0x105e01940>, <__main__.Timing object at 0x105e01a00>, <__main__.Timing object at 0x105e01a60>, <__main__.Timing object at 0x105e01ac0>, <__main__.Timing object at 0x105e01b20>, <__main__.Timing object at 0x105e01b80>, <__main__.Timing object at 0x105e01be0>]}
# {'day': 0, 'open': 1, 'st_time': 800, 'en_time': 1900}
# {'day': 1, 'open': 1, 'st_time': 800, 'en_time': 1900}
# {'day': 2, 'open': 1, 'st_time': 800, 'en_time': 1900}
# {'day': 3, 'open': 1, 'st_time': 800, 'en_time': 1900}
# {'day': 4, 'open': 1, 'st_time': 800, 'en_time': 1900}
# {'day': 5, 'open': 1, 'st_time': 800, 'en_time': 1900}
# {'day': 6, 'open': 1, 'st_time': 800, 'en_time': 1900}
# {'id': 52, 'duration': 2, 'rating': 12.01, 'location': [51.5156174, -0.0913782], 'type': 'Historical & Cultural', 'timings': [<__main__.Timing object at 0x105e01c40>, <__main__.Timing object at 0x105e01d00>, <__main__.Timing object at 0x105e01d60>, <__main__.Timing object at 0x105e01dc0>, <__main__.Timing object at 0x105e01e20>, <__main__.Timing object at 0x105e01e80>, <__main__.Timing object at 0x105e01ee0>]}
# {'day': 0, 'open': 1, 'st_time': 1030, 'en_time': 1600}
# {'day': 1, 'open': 1, 'st_time': 1030, 'en_time': 1600}
# {'day': 2, 'open': 1, 'st_time': 1030, 'en_time': 1600}
# {'day': 3, 'open': 1, 'st_time': 1030, 'en_time': 1600}
# {'day': 4, 'open': 1, 'st_time': 1030, 'en_time': 1600}
# {'day': 5, 'open': 1, 'st_time': 1030, 'en_time': 1600}
# {'day': 6, 'open': 1, 'st_time': 1030, 'en_time': 1600}
# {'id': 55, 'duration': 3, 'rating': 11.07, 'location': [51.53774259999999, -0.0758198], 'type': 'Food & Drinks', 'timings': [<__main__.Timing object at 0x105e01f40>, <__main__.Timing object at 0x105e04040>, <__main__.Timing object at 0x105e040a0>, <__main__.Timing object at 0x105e04100>, <__main__.Timing object at 0x105e04160>, <__main__.Timing object at 0x105e041c0>, <__main__.Timing object at 0x105e04220>]}
# {'day': 0, 'open': 1, 'st_time': 930, 'en_time': 1730}
# {'day': 1, 'open': 1, 'st_time': 930, 'en_time': 1730}
# {'day': 2, 'open': 1, 'st_time': 930, 'en_time': 1730}
# {'day': 3, 'open': 1, 'st_time': 930, 'en_time': 1730}
# {'day': 4, 'open': 1, 'st_time': 930, 'en_time': 1730}
# {'day': 5, 'open': 1, 'st_time': 1400, 'en_time': 1700}
# {'day': 6, 'open': 0, 'st_time': -1, 'en_time': -1}
# {'id': 56, 'duration': 2, 'rating': 10.9, 'location': [51.5258382, -0.2652724999999999], 'type': 'Food & Drinks', 'timings': [<__main__.Timing object at 0x105e04280>, <__main__.Timing object at 0x105e04340>, <__main__.Timing object at 0x105e043a0>, <__main__.Timing object at 0x105e04400>, <__main__.Timing object at 0x105e04460>, <__main__.Timing object at 0x105e044c0>, <__main__.Timing object at 0x105e04520>]}
# {'day': 0, 'open': 1, 'st_time': 900, 'en_time': 1700}
# {'day': 1, 'open': 1, 'st_time': 900, 'en_time': 1700}
# {'day': 2, 'open': 1, 'st_time': 900, 'en_time': 1700}
# {'day': 3, 'open': 1, 'st_time': 900, 'en_time': 1700}
# {'day': 4, 'open': 1, 'st_time': 900, 'en_time': 1700}
# {'day': 5, 'open': 1, 'st_time': 900, 'en_time': 1400}
# {'day': 6, 'open': 0, 'st_time': -1, 'en_time': -1}
# {'id': 57, 'duration': 2, 'rating': 10.76, 'location': [51.51969359999999, -0.1168957], 'type': 'Historical & Cultural', 'timings': [<__main__.Timing object at 0x105e04580>, <__main__.Timing object at 0x105e04640>, <__main__.Timing object at 0x105e046a0>, <__main__.Timing object at 0x105e04700>, <__main__.Timing object at 0x105e04760>, <__main__.Timing object at 0x105e047c0>, <__main__.Timing object at 0x105e04820>]}
# {'day': 0, 'open': 0, 'st_time': -1, 'en_time': -1}
# {'day': 1, 'open': 1, 'st_time': 1100, 'en_time': 1800}
# {'day': 2, 'open': 1, 'st_time': 1100, 'en_time': 1800}
# {'day': 3, 'open': 1, 'st_time': 1200, 'en_time': 2000}
# {'day': 4, 'open': 1, 'st_time': 1100, 'en_time': 1800}
# {'day': 5, 'open': 1, 'st_time': 1100, 'en_time': 1800}
# {'day': 6, 'open': 1, 'st_time': 1200, 'en_time': 1800}
# {'id': 59, 'duration': 2, 'rating': 11.43, 'location': [51.4875836, -0.1575795], 'type': 'Historical & Cultural', 'timings': [<__main__.Timing object at 0x105e04880>, <__main__.Timing object at 0x105e04940>, <__main__.Timing object at 0x105e049a0>, <__main__.Timing object at 0x105e04a00>, <__main__.Timing object at 0x105e04a60>, <__main__.Timing object at 0x105e04ac0>, <__main__.Timing object at 0x105e04b20>]}
# {'day': 0, 'open': 1, 'st_time': 1000, 'en_time': 1800}
# {'day': 1, 'open': 1, 'st_time': 1000, 'en_time': 1800}
# {'day': 2, 'open': 1, 'st_time': 1000, 'en_time': 1800}
# {'day': 3, 'open': 1, 'st_time': 1000, 'en_time': 1800}
# {'day': 4, 'open': 1, 'st_time': 1000, 'en_time': 1800}
# {'day': 5, 'open': 1, 'st_time': 1000, 'en_time': 1800}
# {'day': 6, 'open': 1, 'st_time': 1000, 'en_time': 1800}
# {'id': 62, 'duration': 1, 'rating': 11.27, 'location': [51.5094167, -0.0793083], 'type': 'Historical & Cultural', 'timings': [<__main__.Timing object at 0x105e04b80>, <__main__.Timing object at 0x105e04c40>, <__main__.Timing object at 0x105e04ca0>, <__main__.Timing object at 0x105e04d00>, <__main__.Timing object at 0x105e04d60>, <__main__.Timing object at 0x105e04dc0>, <__main__.Timing object at 0x105e04e20>]}
# {'day': 0, 'open': 1, 'st_time': 800, 'en_time': 1700}
# {'day': 1, 'open': 1, 'st_time': 800, 'en_time': 1700}
# {'day': 2, 'open': 1, 'st_time': 800, 'en_time': 1700}
# {'day': 3, 'open': 1, 'st_time': 800, 'en_time': 1700}
# {'day': 4, 'open': 1, 'st_time': 800, 'en_time': 1700}
# {'day': 5, 'open': 1, 'st_time': 1000, 'en_time': 1700}
# {'day': 6, 'open': 1, 'st_time': 1000, 'en_time': 1700}
# {'id': 63, 'duration': 2, 'rating': 11.21, 'location': [51.49068459999999, -0.2521084], 'type': 'Food & Drinks', 'timings': [<__main__.Timing object at 0x105e04e80>, <__main__.Timing object at 0x105e04f40>, <__main__.Timing object at 0x105e04fa0>, <__main__.Timing object at 0x105e07040>, <__main__.Timing object at 0x105e070a0>, <__main__.Timing object at 0x105e07100>, <__main__.Timing object at 0x105e07160>]}
# {'day': 0, 'open': 1, 'st_time': 900, 'en_time': 1800}
# {'day': 1, 'open': 1, 'st_time': 900, 'en_time': 1800}
# {'day': 2, 'open': 1, 'st_time': 900, 'en_time': 1800}
# {'day': 3, 'open': 1, 'st_time': 900, 'en_time': 1800}
# {'day': 4, 'open': 1, 'st_time': 900, 'en_time': 1600}
# {'day': 5, 'open': 0, 'st_time': -1, 'en_time': -1}
# {'day': 6, 'open': 0, 'st_time': -1, 'en_time': -1}
# {'id': 64, 'duration': 2, 'rating': 10.97, 'location': [51.5236557, -0.1327763], 'type': 'Historical & Cultural', 'timings': [<__main__.Timing object at 0x105e071c0>, <__main__.Timing object at 0x105e07280>, <__main__.Timing object at 0x105e072e0>, <__main__.Timing object at 0x105e07340>, <__main__.Timing object at 0x105e073a0>, <__main__.Timing object at 0x105e07400>, <__main__.Timing object at 0x105e07460>]}
# {'day': 0, 'open': 0, 'st_time': -1, 'en_time': -1}
# {'day': 1, 'open': 1, 'st_time': 1300, 'en_time': 1700}
# {'day': 2, 'open': 1, 'st_time': 1300, 'en_time': 1700}
# {'day': 3, 'open': 1, 'st_time': 1300, 'en_time': 1700}
# {'day': 4, 'open': 1, 'st_time': 1300, 'en_time': 1700}
# {'day': 5, 'open': 1, 'st_time': 1100, 'en_time': 1700}
# {'day': 6, 'open': 0, 'st_time': -1, 'en_time': -1}
# {'id': 65, 'duration': 2, 'rating': 14.84, 'location': [51.53013809999999, -0.0744273], 'type': 'Food & Drinks', 'timings': [<__main__.Timing object at 0x105e074c0>, <__main__.Timing object at 0x105e07580>, <__main__.Timing object at 0x105e075e0>, <__main__.Timing object at 0x105e07640>, <__main__.Timing object at 0x105e076a0>, <__main__.Timing object at 0x105e07700>, <__main__.Timing object at 0x105e07760>]}
# {'day': 0, 'open': 0, 'st_time': -1, 'en_time': -1}
# {'day': 1, 'open': 1, 'st_time': 1835, 'en_time': 2050}
# {'day': 2, 'open': 1, 'st_time': 1835, 'en_time': 2050}
# {'day': 3, 'open': 1, 'st_time': 1835, 'en_time': 2315}
# {'day': 4, 'open': 1, 'st_time': 1610, 'en_time': 2315}
# {'day': 5, 'open': 1, 'st_time': 1130, 'en_time': 2315}
# {'day': 6, 'open': 1, 'st_time': 1200, 'en_time': 2245}
# {'id': 83, 'duration': 2, 'rating': 16.61, 'location': [51.51158650000001, -0.1175593], 'type': 'Historical & Cultural', 'timings': [<__main__.Timing object at 0x105e077c0>, <__main__.Timing object at 0x105e07880>, <__main__.Timing object at 0x105e078e0>, <__main__.Timing object at 0x105e07940>, <__main__.Timing object at 0x105e079a0>, <__main__.Timing object at 0x105e07a00>, <__main__.Timing object at 0x105e07a60>]}
# {'day': 0, 'open': 1, 'st_time': 1000, 'en_time': 1800}
# {'day': 1, 'open': 1, 'st_time': 1000, 'en_time': 1800}
# {'day': 2, 'open': 1, 'st_time': 1000, 'en_time': 1800}
# {'day': 3, 'open': 1, 'st_time': 1000, 'en_time': 1800}
# {'day': 4, 'open': 1, 'st_time': 1000, 'en_time': 1800}
# {'day': 5, 'open': 1, 'st_time': 1000, 'en_time': 1800}
# {'day': 6, 'open': 1, 'st_time': 1000, 'en_time': 1800}
# {'id': 87, 'duration': 3, 'rating': 13.13, 'location': [51.51478259999999, -0.07803629999999999], 'type': 'Food & Drinks', 'timings': [<__main__.Timing object at 0x105e07ac0>, <__main__.Timing object at 0x105e07b80>, <__main__.Timing object at 0x105e07be0>, <__main__.Timing object at 0x105e07c40>, <__main__.Timing object at 0x105e07ca0>, <__main__.Timing object at 0x105e07d00>, <__main__.Timing object at 0x105e07d60>]}
# {'day': 0, 'open': 0, 'st_time': -1, 'en_time': -1}
# {'day': 1, 'open': 0, 'st_time': -1, 'en_time': -1}
# {'day': 2, 'open': 1, 'st_time': 1905, 'en_time': 2050}
# {'day': 3, 'open': 1, 'st_time': 1905, 'en_time': 2050}
# {'day': 4, 'open': 1, 'st_time': 1905, 'en_time': 2315}
# {'day': 5, 'open': 1, 'st_time': 1200, 'en_time': 2315}
# {'day': 6, 'open': 1, 'st_time': 1640, 'en_time': 1825}
# {'id': 89, 'duration': 2, 'rating': 12.34, 'location': [51.52087280000001, -0.05260040000000001], 'type': 'Food & Drinks', 'timings': [<__main__.Timing object at 0x105e07dc0>, <__main__.Timing object at 0x105e07e80>, <__main__.Timing object at 0x105e07ee0>, <__main__.Timing object at 0x105e07f40>, <__main__.Timing object at 0x105e07fa0>, <__main__.Timing object at 0x105e0a040>, <__main__.Timing object at 0x105e0a0a0>]}
# {'day': 0, 'open': 0, 'st_time': -1, 'en_time': -1}
# {'day': 1, 'open': 1, 'st_time': 1500, 'en_time': 2100}
# {'day': 2, 'open': 1, 'st_time': 1500, 'en_time': 2100}
# {'day': 3, 'open': 1, 'st_time': 1500, 'en_time': 2100}
# {'day': 4, 'open': 1, 'st_time': 1500, 'en_time': 2200}
# {'day': 5, 'open': 1, 'st_time': 1100, 'en_time': 2300}
# {'day': 6, 'open': 1, 'st_time': 1100, 'en_time': 2100}
# {'id': 90, 'duration': 4, 'rating': 13.74, 'location': [51.5140478, -0.1306776], 'type': 'Food & Drinks', 'timings': [<__main__.Timing object at 0x105e0a100>, <__main__.Timing object at 0x105e0a1c0>, <__main__.Timing object at 0x105e0a220>, <__main__.Timing object at 0x105e0a280>, <__main__.Timing object at 0x105e0a2e0>, <__main__.Timing object at 0x105e0a340>, <__main__.Timing object at 0x105e0a3a0>]}
# {'day': 0, 'open': 1, 'st_time': 1700, 'en_time': 300}
# {'day': 1, 'open': 1, 'st_time': 1700, 'en_time': 300}
# {'day': 2, 'open': 1, 'st_time': 1700, 'en_time': 300}
# {'day': 3, 'open': 1, 'st_time': 1700, 'en_time': 300}
# {'day': 4, 'open': 1, 'st_time': 1700, 'en_time': 300}
# {'day': 5, 'open': 1, 'st_time': 1500, 'en_time': 300}
# {'day': 6, 'open': 1, 'st_time': 1700, 'en_time': 0}
# {'id': 95, 'duration': 4, 'rating': 13.02, 'location': [51.5114978, -0.134327], 'type': 'Food & Drinks', 'timings': [<__main__.Timing object at 0x105e0a400>, <__main__.Timing object at 0x105e0a4c0>, <__main__.Timing object at 0x105e0a520>, <__main__.Timing object at 0x105e0a580>, <__main__.Timing object at 0x105e0a5e0>, <__main__.Timing object at 0x105e0a640>, <__main__.Timing object at 0x105e0a6a0>]}
# {'day': 0, 'open': 1, 'st_time': 1600, 'en_time': 2330}
# {'day': 1, 'open': 1, 'st_time': 1600, 'en_time': 2330}
# {'day': 2, 'open': 1, 'st_time': 1600, 'en_time': 2330}
# {'day': 3, 'open': 1, 'st_time': 1500, 'en_time': 2330}
# {'day': 4, 'open': 1, 'st_time': 1400, 'en_time': 0}
# {'day': 5, 'open': 1, 'st_time': 1400, 'en_time': 0}
# {'day': 6, 'open': 1, 'st_time': 1600, 'en_time': 2230}
# {'id': 98, 'duration': 4, 'rating': 12.84, 'location': [51.50451349999999, -0.1225601], 'type': 'Food & Drinks', 'timings': [<__main__.Timing object at 0x105e0a700>, <__main__.Timing object at 0x105e0a7c0>, <__main__.Timing object at 0x105e0a820>, <__main__.Timing object at 0x105e0a880>, <__main__.Timing object at 0x105e0a8e0>, <__main__.Timing object at 0x105e0a940>, <__main__.Timing object at 0x105e0a9a0>]}
# {'day': 0, 'open': 1, 'st_time': 1615, 'en_time': 400}
# {'day': 1, 'open': 1, 'st_time': 1615, 'en_time': 400}
# {'day': 2, 'open': 1, 'st_time': 1615, 'en_time': 400}
# {'day': 3, 'open': 1, 'st_time': 1615, 'en_time': 400}
# {'day': 4, 'open': 1, 'st_time': 1615, 'en_time': 400}
# {'day': 5, 'open': 1, 'st_time': 1615, 'en_time': 400}
# {'day': 6, 'open': 1, 'st_time': 1615, 'en_time': 400}
# {'id': 101, 'duration': 3, 'rating': 13.2, 'location': [51.5117923, -0.1201668], 'type': 'Food & Drinks', 'timings': [<__main__.Timing object at 0x105e0aa00>, <__main__.Timing object at 0x105e0aac0>, <__main__.Timing object at 0x105e0ab20>, <__main__.Timing object at 0x105e0ab80>, <__main__.Timing object at 0x105e0abe0>, <__main__.Timing object at 0x105e0ac40>, <__main__.Timing object at 0x105e0aca0>]}
# {'day': 0, 'open': 1, 'st_time': 1600, 'en_time': 2330}
# {'day': 1, 'open': 1, 'st_time': 1600, 'en_time': 2330}
# {'day': 2, 'open': 1, 'st_time': 1600, 'en_time': 2330}
# {'day': 3, 'open': 1, 'st_time': 1500, 'en_time': 2330}
# {'day': 4, 'open': 1, 'st_time': 1300, 'en_time': 0}
# {'day': 5, 'open': 1, 'st_time': 1300, 'en_time': 0}
# {'day': 6, 'open': 1, 'st_time': 1600, 'en_time': 2230}
# {'id': 103, 'duration': 2, 'rating': 11.94, 'location': [51.51890700000001, -0.07826390000000001], 'type': 'Food & Drinks', 'timings': [<__main__.Timing object at 0x105e0ad00>, <__main__.Timing object at 0x105e0adc0>, <__main__.Timing object at 0x105e0ae20>, <__main__.Timing object at 0x105e0ae80>, <__main__.Timing object at 0x105e0aee0>, <__main__.Timing object at 0x105e0af40>, <__main__.Timing object at 0x105e0afa0>]}
# {'day': 0, 'open': 1, 'st_time': 1600, 'en_time': 100}
# {'day': 1, 'open': 1, 'st_time': 1600, 'en_time': 100}
# {'day': 2, 'open': 1, 'st_time': 1600, 'en_time': 100}
# {'day': 3, 'open': 1, 'st_time': 1500, 'en_time': 200}
# {'day': 4, 'open': 1, 'st_time': 1500, 'en_time': 200}
# {'day': 5, 'open': 1, 'st_time': 1300, 'en_time': 200}
# {'day': 6, 'open': 1, 'st_time': 1500, 'en_time': 100}
# {'id': 105, 'duration': 3, 'rating': 11.92, 'location': [51.46065480000001, -0.1673858], 'type': 'Food & Drinks', 'timings': [<__main__.Timing object at 0x105e0d040>, <__main__.Timing object at 0x105e0d100>, <__main__.Timing object at 0x105e0d160>, <__main__.Timing object at 0x105e0d1c0>, <__main__.Timing object at 0x105e0d220>, <__main__.Timing object at 0x105e0d280>, <__main__.Timing object at 0x105e0d2e0>]}
# {'day': 0, 'open': 1, 'st_time': 1700, 'en_time': 0}
# {'day': 1, 'open': 1, 'st_time': 1700, 'en_time': 0}
# {'day': 2, 'open': 1, 'st_time': 1700, 'en_time': 0}
# {'day': 3, 'open': 1, 'st_time': 1700, 'en_time': 200}
# {'day': 4, 'open': 1, 'st_time': 1600, 'en_time': 200}
# {'day': 5, 'open': 1, 'st_time': 1400, 'en_time': 200}
# {'day': 6, 'open': 1, 'st_time': 1700, 'en_time': 0}
# {'id': 107, 'duration': 3, 'rating': 12.0, 'location': [51.5118693, -0.1384912], 'type': 'Food & Drinks', 'timings': [<__main__.Timing object at 0x105e0d340>, <__main__.Timing object at 0x105e0d400>, <__main__.Timing object at 0x105e0d460>, <__main__.Timing object at 0x105e0d4c0>, <__main__.Timing object at 0x105e0d520>, <__main__.Timing object at 0x105e0d580>, <__main__.Timing object at 0x105e0d5e0>]}
# {'day': 0, 'open': 1, 'st_time': 1600, 'en_time': 100}
# {'day': 1, 'open': 1, 'st_time': 1600, 'en_time': 300}
# {'day': 2, 'open': 1, 'st_time': 1600, 'en_time': 300}
# {'day': 3, 'open': 1, 'st_time': 1500, 'en_time': 300}
# {'day': 4, 'open': 1, 'st_time': 1400, 'en_time': 300}
# {'day': 5, 'open': 1, 'st_time': 1300, 'en_time': 300}
# {'day': 6, 'open': 1, 'st_time': 1500, 'en_time': 0}
# {'id': 114, 'duration': 2, 'rating': 11.57, 'location': [51.48535249999999, -0.1235324], 'type': 'Food & Drinks', 'timings': [<__main__.Timing object at 0x105e0d640>, <__main__.Timing object at 0x105e0d700>, <__main__.Timing object at 0x105e0d760>, <__main__.Timing object at 0x105e0d7c0>, <__main__.Timing object at 0x105e0d820>, <__main__.Timing object at 0x105e0d880>, <__main__.Timing object at 0x105e0d8e0>]}
# {'day': 0, 'open': 1, 'st_time': 1700, 'en_time': 2230}
# {'day': 1, 'open': 1, 'st_time': 1700, 'en_time': 2230}
# {'day': 2, 'open': 1, 'st_time': 1700, 'en_time': 2230}
# {'day': 3, 'open': 1, 'st_time': 1700, 'en_time': 2230}
# {'day': 4, 'open': 1, 'st_time': 1700, 'en_time': 2230}
# {'day': 5, 'open': 1, 'st_time': 1200, 'en_time': 2230}
# {'day': 6, 'open': 1, 'st_time': 1200, 'en_time': 2230}
# {'id': 117, 'duration': 3, 'rating': 10.46, 'location': [51.5031593, -0.0002199], 'type': 'Food & Drinks', 'timings': [<__main__.Timing object at 0x105e0d940>, <__main__.Timing object at 0x105e0da00>, <__main__.Timing object at 0x105e0da60>, <__main__.Timing object at 0x105e0dac0>, <__main__.Timing object at 0x105e0db20>, <__main__.Timing object at 0x105e0db80>, <__main__.Timing object at 0x105e0dbe0>]}
# {'day': 0, 'open': 1, 'st_time': 1000, 'en_time': 1800}
# {'day': 1, 'open': 1, 'st_time': 1000, 'en_time': 1800}
# {'day': 2, 'open': 1, 'st_time': 1000, 'en_time': 1800}
# {'day': 3, 'open': 1, 'st_time': 1000, 'en_time': 1800}
# {'day': 4, 'open': 1, 'st_time': 1000, 'en_time': 1800}
# {'day': 5, 'open': 1, 'st_time': 1000, 'en_time': 1800}
# {'day': 6, 'open': 1, 'st_time': 1000, 'en_time': 1800}
# {'id': 120, 'duration': 4, 'rating': 12.23, 'location': [51.5130049, -0.1209407], 'type': 'Food & Drinks', 'timings': [<__main__.Timing object at 0x105e0dc40>, <__main__.Timing object at 0x105e0dd00>, <__main__.Timing object at 0x105e0dd60>, <__main__.Timing object at 0x105e0ddc0>, <__main__.Timing object at 0x105e0de20>, <__main__.Timing object at 0x105e0de80>, <__main__.Timing object at 0x105e0dee0>]}
# {'day': 0, 'open': 1, 'st_time': 1630, 'en_time': 300}
# {'day': 1, 'open': 1, 'st_time': 1630, 'en_time': 300}
# {'day': 2, 'open': 1, 'st_time': 1630, 'en_time': 300}
# {'day': 3, 'open': 1, 'st_time': 1630, 'en_time': 300}
# {'day': 4, 'open': 1, 'st_time': 1630, 'en_time': 300}
# {'day': 5, 'open': 1, 'st_time': 1400, 'en_time': 300}
# {'day': 6, 'open': 1, 'st_time': 1630, 'en_time': 30}
# {'id': 121, 'duration': 2, 'rating': 10.59, 'location': [51.5136885, -0.3065658], 'type': 'Food & Drinks', 'timings': [<__main__.Timing object at 0x105e0df40>, <__main__.Timing object at 0x105e12040>, <__main__.Timing object at 0x105e120a0>, <__main__.Timing object at 0x105e12100>, <__main__.Timing object at 0x105e12160>, <__main__.Timing object at 0x105e121c0>, <__main__.Timing object at 0x105e12220>]}
# {'day': 0, 'open': 1, 'st_time': 1400, 'en_time': 2200}
# {'day': 1, 'open': 1, 'st_time': 1400, 'en_time': 2200}
# {'day': 2, 'open': 1, 'st_time': 1400, 'en_time': 2200}
# {'day': 3, 'open': 1, 'st_time': 1400, 'en_time': 2200}
# {'day': 4, 'open': 1, 'st_time': 1400, 'en_time': 2200}
# {'day': 5, 'open': 1, 'st_time': 1000, 'en_time': 2200}
# {'day': 6, 'open': 1, 'st_time': 1000, 'en_time': 2100}
# {'id': 122, 'duration': 4, 'rating': 12.44, 'location': [51.5159722, -0.1475004], 'type': 'Food & Drinks', 'timings': [<__main__.Timing object at 0x105e12280>, <__main__.Timing object at 0x105e12340>, <__main__.Timing object at 0x105e123a0>, <__main__.Timing object at 0x105e12400>, <__main__.Timing object at 0x105e12460>, <__main__.Timing object at 0x105e124c0>, <__main__.Timing object at 0x105e12520>]}
# {'day': 0, 'open': 1, 'st_time': 1600, 'en_time': 0}
# {'day': 1, 'open': 1, 'st_time': 1600, 'en_time': 0}
# {'day': 2, 'open': 1, 'st_time': 1600, 'en_time': 0}
# {'day': 3, 'open': 1, 'st_time': 1600, 'en_time': 100}
# {'day': 4, 'open': 1, 'st_time': 1500, 'en_time': 100}
# {'day': 5, 'open': 1, 'st_time': 1600, 'en_time': 100}
# {'day': 6, 'open': 1, 'st_time': 1600, 'en_time': 2330}
# {'id': 125, 'duration': 4, 'rating': 10.65, 'location': [51.49364840000001, -0.2240724], 'type': 'Food & Drinks', 'timings': [<__main__.Timing object at 0x105e12580>, <__main__.Timing object at 0x105e12640>, <__main__.Timing object at 0x105e126a0>, <__main__.Timing object at 0x105e12700>, <__main__.Timing object at 0x105e12760>, <__main__.Timing object at 0x105e127c0>, <__main__.Timing object at 0x105e12820>]}
# {'day': 0, 'open': 1, 'st_time': 1700, 'en_time': 0}
# {'day': 1, 'open': 1, 'st_time': 1700, 'en_time': 0}
# {'day': 2, 'open': 1, 'st_time': 1700, 'en_time': 0}
# {'day': 3, 'open': 1, 'st_time': 1700, 'en_time': 200}
# {'day': 4, 'open': 1, 'st_time': 1600, 'en_time': 200}
# {'day': 5, 'open': 1, 'st_time': 1500, 'en_time': 200}
# {'day': 6, 'open': 1, 'st_time': 1700, 'en_time': 0}
# {'id': 137, 'duration': 4, 'rating': 10.28, 'location': [51.5180209, -0.1346286], 'type': 'Food & Drinks', 'timings': [<__main__.Timing object at 0x105e12880>, <__main__.Timing object at 0x105e12940>, <__main__.Timing object at 0x105e129a0>, <__main__.Timing object at 0x105e12a00>, <__main__.Timing object at 0x105e12a60>, <__main__.Timing object at 0x105e12ac0>, <__main__.Timing object at 0x105e12b20>]}
# {'day': 0, 'open': 0, 'st_time': -1, 'en_time': -1}
# {'day': 1, 'open': 1, 'st_time': 1000, 'en_time': 1800}
# {'day': 2, 'open': 1, 'st_time': 1000, 'en_time': 1800}
# {'day': 3, 'open': 1, 'st_time': 1000, 'en_time': 1800}
# {'day': 4, 'open': 1, 'st_time': 1000, 'en_time': 1800}
# {'day': 5, 'open': 1, 'st_time': 1000, 'en_time': 1800}
# {'day': 6, 'open': 1, 'st_time': 1000, 'en_time': 1800}
# {'id': 138, 'duration': 2, 'rating': 11.05, 'location': [51.5202413, -0.1004441], 'type': 'Food & Drinks', 'timings': [<__main__.Timing object at 0x105e12b80>, <__main__.Timing object at 0x105e12c40>, <__main__.Timing object at 0x105e12ca0>, <__main__.Timing object at 0x105e12d00>, <__main__.Timing object at 0x105e12d60>, <__main__.Timing object at 0x105e12dc0>, <__main__.Timing object at 0x105e12e20>]}
# {'day': 0, 'open': 1, 'st_time': 1630, 'en_time': 0}
# {'day': 1, 'open': 1, 'st_time': 1630, 'en_time': 0}
# {'day': 2, 'open': 1, 'st_time': 1630, 'en_time': 0}
# {'day': 3, 'open': 1, 'st_time': 1630, 'en_time': 200}
# {'day': 4, 'open': 1, 'st_time': 1630, 'en_time': 200}
# {'day': 5, 'open': 1, 'st_time': 1500, 'en_time': 200}
# {'day': 6, 'open': 0, 'st_time': -1, 'en_time': -1}
# {'id': 152, 'duration': 4, 'rating': 10.74, 'location': [51.46528379999999, -0.2148811], 'type': 'Food & Drinks', 'timings': [<__main__.Timing object at 0x105e12e80>, <__main__.Timing object at 0x105e12f40>, <__main__.Timing object at 0x105e12fa0>, <__main__.Timing object at 0x105e14040>, <__main__.Timing object at 0x105e140a0>, <__main__.Timing object at 0x105e14100>, <__main__.Timing object at 0x105e14160>]}
# {'day': 0, 'open': 1, 'st_time': 1700, 'en_time': 0}
# {'day': 1, 'open': 1, 'st_time': 1700, 'en_time': 0}
# {'day': 2, 'open': 1, 'st_time': 1700, 'en_time': 0}
# {'day': 3, 'open': 1, 'st_time': 1700, 'en_time': 0}
# {'day': 4, 'open': 1, 'st_time': 1700, 'en_time': 200}
# {'day': 5, 'open': 1, 'st_time': 1600, 'en_time': 200}
# {'day': 6, 'open': 1, 'st_time': 1700, 'en_time': 0}
# {'id': 155, 'duration': 2, 'rating': 8.88, 'location': [51.5120001, -0.1275659], 'type': 'Food & Drinks', 'timings': [<__main__.Timing object at 0x105e141c0>, <__main__.Timing object at 0x105e14280>, <__main__.Timing object at 0x105e142e0>, <__main__.Timing object at 0x105e14340>, <__main__.Timing object at 0x105e143a0>, <__main__.Timing object at 0x105e14400>, <__main__.Timing object at 0x105e14460>]}
# {'day': 0, 'open': 1, 'st_time': 1915, 'en_time': 2200}
# {'day': 1, 'open': 1, 'st_time': 1915, 'en_time': 2200}
# {'day': 2, 'open': 1, 'st_time': 1915, 'en_time': 2200}
# {'day': 3, 'open': 1, 'st_time': 1915, 'en_time': 2200}
# {'day': 4, 'open': 0, 'st_time': -1, 'en_time': -1}
# {'day': 5, 'open': 0, 'st_time': -1, 'en_time': -1}
# {'day': 6, 'open': 0, 'st_time': -1, 'en_time': -1}
# {'id': 157, 'duration': 4, 'rating': 12.5, 'location': [51.51888829999999, -0.1365042], 'type': 'Food & Drinks', 'timings': [<__main__.Timing object at 0x105e144c0>, <__main__.Timing object at 0x105e14580>, <__main__.Timing object at 0x105e145e0>, <__main__.Timing object at 0x105e14640>, <__main__.Timing object at 0x105e146a0>, <__main__.Timing object at 0x105e14700>, <__main__.Timing object at 0x105e14760>]}
# {'day': 0, 'open': 0, 'st_time': -1, 'en_time': -1}
# {'day': 1, 'open': 1, 'st_time': 1600, 'en_time': 2330}
# {'day': 2, 'open': 1, 'st_time': 1600, 'en_time': 2330}
# {'day': 3, 'open': 1, 'st_time': 1600, 'en_time': 2330}
# {'day': 4, 'open': 1, 'st_time': 1600, 'en_time': 0}
# {'day': 5, 'open': 1, 'st_time': 1500, 'en_time': 0}
# {'day': 6, 'open': 0, 'st_time': -1, 'en_time': -1}
# {'id': 160, 'duration': 3, 'rating': 10.46, 'location': [51.5026176, -0.1100641], 'type': 'Food & Drinks', 'timings': [<__main__.Timing object at 0x105e147c0>, <__main__.Timing object at 0x105e14880>, <__main__.Timing object at 0x105e148e0>, <__main__.Timing object at 0x105e14940>, <__main__.Timing object at 0x105e149a0>, <__main__.Timing object at 0x105e14a00>, <__main__.Timing object at 0x105e14a60>]}
# {'day': 0, 'open': 1, 'st_time': 1000, 'en_time': 1800}
# {'day': 1, 'open': 1, 'st_time': 1000, 'en_time': 1800}
# {'day': 2, 'open': 1, 'st_time': 1000, 'en_time': 1800}
# {'day': 3, 'open': 1, 'st_time': 1000, 'en_time': 1800}
# {'day': 4, 'open': 1, 'st_time': 1000, 'en_time': 1800}
# {'day': 5, 'open': 1, 'st_time': 1000, 'en_time': 1800}
# {'day': 6, 'open': 1, 'st_time': 1000, 'en_time': 1800}
# {'id': 170, 'duration': 2, 'rating': 6.69, 'location': [51.5051425, -0.1483173], 'type': 'Historical & Cultural', 'timings': [<__main__.Timing object at 0x105e14ac0>, <__main__.Timing object at 0x105e14b80>, <__main__.Timing object at 0x105e14be0>, <__main__.Timing object at 0x105e14c40>, <__main__.Timing object at 0x105e14ca0>, <__main__.Timing object at 0x105e14d00>, <__main__.Timing object at 0x105e14d60>]}
# {'day': 0, 'open': 1, 'st_time': 1000, 'en_time': 1800}
# {'day': 1, 'open': 1, 'st_time': 1000, 'en_time': 1800}
# {'day': 2, 'open': 1, 'st_time': 1000, 'en_time': 1800}
# {'day': 3, 'open': 1, 'st_time': 1000, 'en_time': 1800}
# {'day': 4, 'open': 1, 'st_time': 1000, 'en_time': 1800}
# {'day': 5, 'open': 1, 'st_time': 1000, 'en_time': 1800}
# {'day': 6, 'open': 1, 'st_time': 1000, 'en_time': 1800}
# {'id': 172, 'duration': 2, 'rating': 6.69, 'location': [51.5287434, -0.0535392], 'type': 'Historical & Cultural', 'timings': [<__main__.Timing object at 0x105e14dc0>, <__main__.Timing object at 0x105e14e80>, <__main__.Timing object at 0x105e14ee0>, <__main__.Timing object at 0x105e14f40>, <__main__.Timing object at 0x105e14fa0>, <__main__.Timing object at 0x105e18040>, <__main__.Timing object at 0x105e180a0>]}
# {'day': 0, 'open': 1, 'st_time': 1000, 'en_time': 1800}
# {'day': 1, 'open': 1, 'st_time': 1000, 'en_time': 1800}
# {'day': 2, 'open': 1, 'st_time': 1000, 'en_time': 1800}
# {'day': 3, 'open': 1, 'st_time': 1000, 'en_time': 1800}
# {'day': 4, 'open': 1, 'st_time': 1000, 'en_time': 1800}
# {'day': 5, 'open': 1, 'st_time': 1000, 'en_time': 1800}
# {'day': 6, 'open': 1, 'st_time': 1000, 'en_time': 1800}
# {'id': 174, 'duration': 1, 'rating': 6.49, 'location': [51.51046170000001, -0.1425691], 'type': 'Historical & Cultural', 'timings': [<__main__.Timing object at 0x105e18100>, <__main__.Timing object at 0x105e181c0>, <__main__.Timing object at 0x105e18220>, <__main__.Timing object at 0x105e18280>, <__main__.Timing object at 0x105e182e0>, <__main__.Timing object at 0x105e18340>, <__main__.Timing object at 0x105e183a0>]}
# {'day': 0, 'open': 1, 'st_time': 800, 'en_time': 2400}
# {'day': 1, 'open': 1, 'st_time': 800, 'en_time': 2400}
# {'day': 2, 'open': 1, 'st_time': 800, 'en_time': 2400}
# {'day': 3, 'open': 1, 'st_time': 800, 'en_time': 2400}
# {'day': 4, 'open': 1, 'st_time': 800, 'en_time': 2400}
# {'day': 5, 'open': 1, 'st_time': 800, 'en_time': 2400}
# {'day': 6, 'open': 1, 'st_time': 800, 'en_time': 2400}
# {'id': 175, 'duration': 1, 'rating': 7.23, 'location': [51.5131099, -0.1589148], 'type': 'Historical & Cultural', 'timings': [<__main__.Timing object at 0x105e18400>, <__main__.Timing object at 0x105e184c0>, <__main__.Timing object at 0x105e18520>, <__main__.Timing object at 0x105e18580>, <__main__.Timing object at 0x105e185e0>, <__main__.Timing object at 0x105e18640>, <__main__.Timing object at 0x105e186a0>]}
# {'day': 0, 'open': 1, 'st_time': 800, 'en_time': 2400}
# {'day': 1, 'open': 1, 'st_time': 800, 'en_time': 2400}
# {'day': 2, 'open': 1, 'st_time': 800, 'en_time': 2400}
# {'day': 3, 'open': 1, 'st_time': 800, 'en_time': 2400}
# {'day': 4, 'open': 1, 'st_time': 800, 'en_time': 2400}
# {'day': 5, 'open': 1, 'st_time': 800, 'en_time': 2400}
# {'day': 6, 'open': 1, 'st_time': 800, 'en_time': 2400}
# {'id': 178, 'duration': 2, 'rating': 9.95, 'location': [51.4860512, -0.1968883], 'type': 'Food & Drinks', 'timings': [<__main__.Timing object at 0x105e18700>, <__main__.Timing object at 0x105e187c0>, <__main__.Timing object at 0x105e18820>, <__main__.Timing object at 0x105e18880>, <__main__.Timing object at 0x105e188e0>, <__main__.Timing object at 0x105e18940>, <__main__.Timing object at 0x105e189a0>]}
# {'day': 0, 'open': 1, 'st_time': 900, 'en_time': 1730}
# {'day': 1, 'open': 1, 'st_time': 900, 'en_time': 1730}
# {'day': 2, 'open': 1, 'st_time': 900, 'en_time': 1730}
# {'day': 3, 'open': 1, 'st_time': 900, 'en_time': 1730}
# {'day': 4, 'open': 1, 'st_time': 900, 'en_time': 1730}
# {'day': 5, 'open': 0, 'st_time': -1, 'en_time': -1}
# {'day': 6, 'open': 0, 'st_time': -1, 'en_time': -1}
# {'id': 180, 'duration': 1, 'rating': 7.03, 'location': [51.5117984, -0.1273864], 'type': 'Historical & Cultural', 'timings': [<__main__.Timing object at 0x105e18a00>, <__main__.Timing object at 0x105e18ac0>, <__main__.Timing object at 0x105e18b20>, <__main__.Timing object at 0x105e18b80>, <__main__.Timing object at 0x105e18be0>, <__main__.Timing object at 0x105e18c40>, <__main__.Timing object at 0x105e18ca0>]}
# {'day': 0, 'open': 1, 'st_time': 800, 'en_time': 2400}
# {'day': 1, 'open': 1, 'st_time': 800, 'en_time': 2400}
# {'day': 2, 'open': 1, 'st_time': 800, 'en_time': 2400}
# {'day': 3, 'open': 1, 'st_time': 800, 'en_time': 2400}
# {'day': 4, 'open': 1, 'st_time': 800, 'en_time': 2400}
# {'day': 5, 'open': 1, 'st_time': 800, 'en_time': 2400}
# {'day': 6, 'open': 1, 'st_time': 800, 'en_time': 2400}

# %% [markdown]
# requirement : {
#     city : string
#     st_date : ?~?
#     en_date : ?~?
#     types : {} // type1, type2, type3 ...
#     exclude : {} // id_1, id_2, id_3 ...
#     include : {
#         {},{},{} // {id_1,st_time, en_time}
#     }
#     duration : {
#
#     }
# }
#
# request : {
#     city : //From Index Page
#     st_date : //From Index Page
#     en_date : //From Index Page
#     types : {} //From Attraction Page
#     exclude : [] //Empty
#     include : [] //Empty
#     duration : [[],[]] //Empty
# }

# %% [markdown]
# itinerary : {
#     day1 : {
#
#     }
# }

# %% [markdown]
# ## Day Iternery
# `Input = [[opening_time,closing_time,duration,[loaction]]]`

# %%
import itertools

def converted_attractions(attractions, day):

  converted_attractions = []

  for attraction in attractions:
    converted_attraction = {
            "id" : attraction.id,
          "opening_time": int(attraction.timings[day].st_time),
          "closing_time": int(attraction.timings[day].en_time),
          "duration": attraction.duration,
          "location": attraction.location
      }
    converted_attractions.append(converted_attraction)

  return converted_attractions


def get_day_iternery(locations):
    # Initialize a list to store the feasible orders of the locations.
    feasible_orders = []

    # Iterate over all combinations of the locations.
    for order in itertools.permutations(locations):
        cur_time = order[0]['opening_time'] + order[0]['duration']
        order_schedule = []  # Store the current order's schedule

        for i in range(1, len(order)):
            cur_time += time_between_locations(order[i - 1]['location'], order[i]['location'])
            cur_time = max(order[i]['opening_time'], cur_time)
            exit_time = cur_time + order[i]['duration']

            if exit_time >= order[i]['closing_time']:
                break

            # Append the id, start time, and end time to the order_schedule
            order_schedule.append([order[i]['id'], cur_time, exit_time])
            cur_time = exit_time

        feasible_orders.append(order_schedule)

    # If there are no feasible orders, return None.
    if not feasible_orders:
        return None
    else:
        return feasible_orders[0]

# Example data
locations = [
    {'id': 1, 'opening_time': 9, 'closing_time': 18, 'duration': 2, 'location': 'A'},
    {'id': 2, 'opening_time': 10, 'closing_time': 18, 'duration': 3, 'location': 'B'},
    {'id': 3, 'opening_time': 11, 'closing_time': 18, 'duration': 2, 'location': 'C'}
]

result = get_day_iternery(locations)
print(result)

# %%
DAY_LIMIT = 6
import heapq
from datetime import datetime

def itenery_scheduler(request):
    print(request)
    request['st_date'] = datetime.strptime(request['st_date'], "%Y-%m-%d").date()
    request['en_date'] = datetime.strptime(request['en_date'], "%Y-%m-%d").date()

    num_types = len(request['types'])
    num_days,start_day =  (request['en_date'] - request['st_date']).days, request['st_date'].weekday()
    daySets = []
    curDate,curDay = request['st_date'],start_day
    for i in range(num_days):
        new_day = DaySet(curDay,curDate,DAY_LIMIT)
        daySets.append(new_day)
    
    type_heaps = {}
    for types in request['types']:
        type_heaps[types] = []
    
    attractions = get_attraction_list(request)

    for attraction in attractions:
        type_heaps[attraction.type].append(attraction)
    
    for types in request['types']:
        heapq.heapify(type_heaps[types])

    typeSets = []

    for types in request['types']:
        typeSets.append(heapq.heappop(type_heaps['types']))    
    
    while(len(daySets)!=0 or len(typeSets)!=0):
        get_rating_matrix(daySets,typeSets)
    
    
    
request = {'city': 'Mumbai', 'st_date': '2023-08-10', 'en_date': '2023-08-11', 'types': ['Historical & Cultural', 'Amusement & Entertainment'], 'exclude': [], 'include': [], 'duration': [[], []]}
itenery_scheduler(request)

# %%
import sqlite3
def get_row(id):
    query = f"""
        SELECT * from Attractions WHERE id = {id}
    """
    conn = sqlite3.connect("../Data/tws.db")
    cursor = conn.cursor()
    cursor.execute(query)
    attractions_results = cursor.fetchall()[0]
    return attractions_results

get_row(934)
# Out:
# (934,
#  0,
#  1,
#  'Haji Ali Mosque',
#  'Sitting on a jetty in the Arabian sea, this spectacular white mosque was built to honor and house the remains of the Muslim saint Haji Ali.',
#  2,
#  12.79,
#  'ChIJ40INk37O5zsRBY0Hq8dd4NU',
#  18.9827269,
#  72.8089112)

# %%
def add_time(t1,t2):
    h1,m1 = t1//100,t1%100
    m1+=t2
    h2,m2 = m1//60, m1%60

    return (h1+h2)*100+m2
add_time(900, 60)
# Out:
# 1000

# %%
import itertools
def get_day_iternery(locations):
    # Initialize a list to store the feasible orders of the locations.
    feasible_orders = []

    # Iterate over all combinations of the locations.
    for order in itertools.permutations(locations):
        cur_time = add_time(order[0]['opening_time'] ,order[0]['duration'])
        order_schedule = [[order[0]['id'],order[0]['opening_time'],cur_time]]  # Store the current order's schedule

        for i in range(1, len(order)):
            travel_time = time_between_locations(order[i - 1]['location'], order[i]['location'])*60
            travel_time = (round(travel_time)//10)*10 +10
            cur_time = add_time(cur_time,travel_time)
            cur_time = max(order[i]['opening_time'], cur_time)
            exit_time = add_time(cur_time ,order[i]['duration'])

            if exit_time > order[i]['closing_time']:
                break

            # Append the id, start time, and end time to the order_schedule
            order_schedule.append([order[i]['id'], cur_time, exit_time])
            cur_time = exit_time

        if len(order_schedule)==len(order):
            feasible_orders.append(order_schedule)

    # If there are no feasible orders, return None.
    if not feasible_orders:
        return None
    else:
        best_idx = 0
        best_time = 100000
        for i in range(len(feasible_orders)):
            tot_time = feasible_orders[i][-1][2]-feasible_orders[i][0][1]
            if tot_time<=best_time:
                best_idx = i
                best_time = tot_time
        return feasible_orders[best_idx]

locations = [{'id': 931, 'opening_time': 1000, 'closing_time': 1800, 'duration': 120, 'location': [17.4292172, 78.32431869999999]}, {'id': 933, 'opening_time': 1000, 'closing_time': 1800, 'duration': 240, 'location': [19.2314895, 72.8075257]}, {'id': 1010, 'opening_time': 1100, 'closing_time': 2300, 'duration': 120, 'location': [19.1353022, 72.83233539999999]}, {'id': 1001, 'opening_time': 1100, 'closing_time': 2300, 'duration': 180, 'location': [19.0999411, 72.9159104]}]

get_day_iternery(locations)

# %%
import sqlite3
from scheduler.constants import *
import json

DB_ADDRESS = "../Data/tws2.db"

def open247(day_results):
    for day in day_results:
        if day[3] == 1:
            return 0
    return 1

def get_timing(id):
    query = f"""
        SELECT * from OperationHours WHERE attraction_id = {id}
    """
    conn = sqlite3.connect(DB_ADDRESS)
    cursor = conn.cursor()
    cursor.execute(query)
    attractions_results = cursor.fetchall()
    if len(attractions_results)==1:
        attractions_results = STD_TIMING
    if open247(attractions_results):
        attractions_results = ALL_TIMING

    timing_data = {}
    
    for index, day_result in enumerate(attractions_results):
        day_dict = {}
        
        day_dict['day'] = DAY_MAP[day_result[2]]  # Get the day name from the list
        day_dict['open'] = 'OPEN' if bool(day_result[3]) else 'CLOSE'  # Convert the 'open' value to a boolean
        day_dict['opening_time'] = int(day_result[4])  # Get the opening time
        day_dict['closing_time'] = day_result[5]  # Get the closing time
        
        timing_data[index]=day_dict
    
    return json.dumps(timing_data)

    
get_timing(1000)
# Out:
# '{"0": {"day": "MON", "open": "OPEN", "opening_time": 1000, "closing_time": "1800"}, "1": {"day": "TUE", "open": "OPEN", "opening_time": 1000, "closing_time": "1800"}, "2": {"day": "WED", "open": "OPEN", "opening_time": 1000, "closing_time": "1800"}, "3": {"day": "THU", "open": "OPEN", "opening_time": 1000, "closing_time": "1800"}, "4": {"day": "FRI", "open": "OPEN", "opening_time": 1000, "closing_time": "1800"}, "5": {"day": "SAT", "open": "OPEN", "opening_time": 1000, "closing_time": "1800"}, "6": {"day": "SUN", "open": "OPEN", "opening_time": 1000, "closing_time": "1800"}}'

# %%
def get_duration(id):
    query = f"""
        SELECT duration from Attractions WHERE id = {id}
    """
    conn = sqlite3.connect(DB_ADDRESS)
    cursor = conn.cursor()
    cursor.execute(query)
    attractions_results = cursor.fetchall()[0][0]
    return attractions_results

get_duration(324)
# Out:
# 1

# %%
def get_city_idx(name):
    # Connect to the SQLite database
    conn = sqlite3.connect('../Data/tws.db')
    cursor = conn.cursor()

    query = f"""
        SELECT id FROM Cities WHERE name= '{name}'
    """
    # Fetch data from the database
    cursor.execute(query)
    data = cursor.fetchall()

    # Close the database connection
    conn.close()

    return data[0][0] 

get_city_idx('Mumbai')
# Out:
# 0

# %%
import requests

# Set the latitude and longitude coordinates
latitude,longitude = [40.7115776,-74.0133362]

latitude,longitude = [19.0168625,72.83045310000001]

# Set the API endpoint
request_url = f"https://nominatim.openstreetmap.org/reverse?lat={latitude}&lon={longitude}"

# Make the request
response = requests.get(request_url)
print(response.content)
# Out:
# b'<?xml version="1.0" encoding="UTF-8" ?>\n<reversegeocode timestamp="Sat, 02 Sep 2023 21:06:00 +00:00" attribution="Data \xc2\xa9 OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright" querystring="lat=19.0168625&amp;lon=72.83045310000001&amp;format=xml"><result place_id="164234648" osm_type="way" osm_id="236614961" ref="\xe0\xa4\xb8\xe0\xa4\xbf\xe0\xa4\xa6\xe0\xa5\x8d\xe0\xa4\xa7\xe0\xa4\xbf\xe0\xa4\xb5\xe0\xa4\xbf\xe0\xa4\xa8\xe0\xa4\xbe\xe0\xa4\xaf\xe0\xa4\x95 \xe0\xa4\xae\xe0\xa4\x82\xe0\xa4\xa6\xe0\xa4\xbf\xe0\xa4\xb0" lat="19.0169869" lon="72.8302725" boundingbox="19.0165709,19.0175282,72.8299696,72.8309914" place_rank="30" address_rank="30">\xe0\xa4\xb8\xe0\xa4\xbf\xe0\xa4\xa6\xe0\xa5\x8d\xe0\xa4\xa7\xe0\xa4\xbf\xe0\xa4\xb5\xe0\xa4\xbf\xe0\xa4\xa8\xe0\xa4\xbe\xe0\xa4\xaf\xe0\xa4\x95 \xe0\xa4\xae\xe0\xa4\x82\xe0\xa4\xa6\xe0\xa4\xbf\xe0\xa4\xb0, Swatantrya Veer Savarkar Marg, G/N Ward, Zone 2, Mumbai, Mumbai City District, Maharashtra, 400025, India</result><addressparts><amenity>\xe0\xa4\xb8\xe0\xa4\xbf\xe0\xa4\xa6\xe0\xa5\x8d\xe0\xa4\xa7\xe0\xa4\xbf\xe0\xa4\xb5\xe0\xa4\xbf\xe0\xa4\xa8\xe0\xa4\xbe\xe0\xa4\xaf\xe0\xa4\x95 \xe0\xa4\xae\xe0\xa4\x82\xe0\xa4\xa6\xe0\xa4\xbf\xe0\xa4\xb0</amenity><road>Swatantrya Veer Savarkar Marg</road><neighbourhood>G/N Ward</neighbourhood><suburb>Zone 2</suburb><city_district>Mumbai</city_district><city>Mumbai City District</city><state>Maharashtra</state><ISO3166-2-lvl4>IN-MH</ISO3166-2-lvl4><postcode>400025</postcode><country>India</country><country_code>in</country_code></addressparts></reversegeocode>'

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[46], line 3
#       1 a = {}
#       2 for i in range(5):
# ----> 3     a.append({})
#       4 a
#
# AttributeError: 'dict' object has no attribute 'append'

# %%
# Import API class from pexels_api package
from pexels_api import API


# Type your Pexels API
PEXELS_API_KEY = 'ARe2hWfm1t82LI4DNHY5jIBokogficcSj5N5NLq82nE7Mxh6M0TExRP1'
# Create API object
api = API(PEXELS_API_KEY)
# Search five 'kitten' photos
api.search('Gateway of India,Mumbai', page=1, results_per_page=5)
# Get photo entries
photos = api.get_entries()

# %%
print(len(photos))
print(photos)

for ele in photos:
    print(ele.original)
# Out:
# 5
# [<pexels_api.tools.photo.Photo object at 0x117194580>, <pexels_api.tools.photo.Photo object at 0x117344280>, <pexels_api.tools.photo.Photo object at 0x117149370>, <pexels_api.tools.photo.Photo object at 0x117149280>, <pexels_api.tools.photo.Photo object at 0x117136dc0>]
# https://images.pexels.com/photos/1371168/pexels-photo-1371168.jpeg
# https://images.pexels.com/photos/2815093/pexels-photo-2815093.jpeg
# https://images.pexels.com/photos/6481558/pexels-photo-6481558.jpeg
# https://images.pexels.com/photos/13091771/pexels-photo-13091771.jpeg
# https://images.pexels.com/photos/6067512/pexels-photo-6067512.jpeg

# %%
from datetime import datetime

# format_time = lambda time_str: datetime.strptime(str(time_str).zfill(4), "%H%M").strftime("%H:%M")

def format_time(tt):
    tt=str(tt).zfill(4)
    h,m = tt[:2],tt[2:]
    return h+":"+m

# %%
def get_photos(id):
    url_list = [
        'https://images.pexels.com/photos/1371168/pexels-photo-1371168.jpeg',
        'https://images.pexels.com/photos/2815093/pexels-photo-2815093.jpeg',
        'https://images.pexels.com/photos/6481558/pexels-photo-6481558.jpeg',
        'https://images.pexels.com/photos/13091771/pexels-photo-13091771.jpeg',
        'https://images.pexels.com/photos/6067512/pexels-photo-6067512.jpeg'
    ]
    return url_list

get_photos(987)
# Out:
# ['https://images.pexels.com/photos/1371168/pexels-photo-1371168.jpeg',
#  'https://images.pexels.com/photos/2815093/pexels-photo-2815093.jpeg',
#  'https://images.pexels.com/photos/6481558/pexels-photo-6481558.jpeg',
#  'https://images.pexels.com/photos/13091771/pexels-photo-13091771.jpeg',
#  'https://images.pexels.com/photos/6067512/pexels-photo-6067512.jpeg']
